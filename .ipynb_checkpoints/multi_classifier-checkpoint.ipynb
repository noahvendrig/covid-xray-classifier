# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2
from PIL import Image
import os

# %%
# how to process img into numpy using Pillow
image = Image.open('./dataset/covid/images/COVID-1.png')
npimg = np.asarray(image,dtype="int32")
npimg.shape
# Out:
# (299, 299)

# %%
# How to process img into numpy using OpenCV
def ImageToArray(path):
    img_arr = cv2.imread(path)   # reads an image in the BGR format
    img_arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)   # BGR -> RGB
    return img_arr

# %%
plt.imshow(npimg)
plt.show()

# %%
labels= ['normal','covid','pneumonia']
X = np.empty()
y = []
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-09a698f474dd> in <module>
#       1 labels= ['normal','covid','pneumonia']
# ----> 2 X = np.empty()
#       3 y = []
#
# TypeError: empty() missing required argument 'shape' (pos 0)

# %%
curr_type = "covid"
testim = ImageToArray(f"./dataset/{curr_type}/images/COVID-1.png")/255

# %%
#testim

# %%
plt.imshow(testim)
plt.show()

# %%
for label in labels:
    for filename in os.listdir(f"./dataset/{label}/images/")[:20]:
        arr = ImageToArray(f"./dataset/{label}/images/{filename}")/255 # dont run this yet cos it eats up processing power
        np.append(X, arr)
        label_index = labels.index(label)
        y.append(label_index)
        #print(filename, label_index) # yep it goes through all of them correctly
        
        
X = np.array(X)

# %%
# X[:3]
X.shape
# y[0]
# y.shape
# Out:
# (330, 299, 299, 3)

# %%
X
# plt.imshow(X[0])
# plt.show()

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-103-73edc048c06b> in <module>
# ----> 1 from sklearn.model_selection import train_test_split
#
# ~\anaconda3\envs\noah\lib\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~\anaconda3\envs\noah\lib\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# ~\anaconda3\envs\noah\lib\site-packages\sklearn\utils\__init__.py in <module>
#      19 import warnings
#      20 import numpy as np
# ---> 21 from scipy.sparse import issparse
#      22
#      23 from .murmurhash import murmurhash3_32
#
# ImportError: cannot import name 'issparse' from 'scipy.sparse' (unknown location)

# %%
(X_train, y_train), (X_test, y_test) = train_test_split(X, y, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-42a49da37d15> in <module>
# ----> 1 (X_train, y_train), (X_test, y_test) = train_test_split(X, y, test_size=0.2)
#
# NameError: name 'train_test_split' is not defined

# %%
from tensorflow.keras import datasets
(X_train, y_train),(X_test, y_test)=datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 254s 1us/step
# 170508288/170498071 [==============================] - 254s 1us/step

# %%
X_train, X_test = X_train/255, X_test/255

# %%
 X_train[0] # X_train is just a collection of all the np arrays of each image
y_train[0] # y_train just has all the labels for image of corresponding index
# Out:
# 32

# %%
plt.imshow(X_train[0])
# Out:
# array([6], dtype=uint8)
